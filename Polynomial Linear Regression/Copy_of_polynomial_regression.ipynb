# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragjha0936/Machine-learning-/blob/main/Polynomial%20Linear%20Regression/Copy_of_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df=pd.read_csv("Position_Salaries.csv")
x=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
x_poly=poly_reg.fit_transform(x)
lin_reg=LinearRegression()
lin_reg.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y,color="blue")
plt.plot(x,regressor.predict(x),color="green")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x,y, color="blue")
plt.plot(x,lin_reg.predict(x_poly),"green")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher Degree)

# %%
poly_reg_2=PolynomialFeatures(degree=4)
x_poly_2=poly_reg_2.fit_transform(x)
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly_2,y)
plt.scatter(x,y,color="blue")
plt.plot(x,lin_reg_2.predict(x_poly_2),color="green")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
print(regressor.predict([[6.5]]))
# Out:
# [330378.78787879]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
print(lin_reg_2.predict(poly_reg_2.fit_transform([[6.5]])))
# Out:
# [158862.45265155]
